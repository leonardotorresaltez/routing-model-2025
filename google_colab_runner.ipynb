# %%
# !curl -sSL https://install.python-poetry.org | python3 -

# %%
import os
os.environ['PATH'] += ":/root/.local/bin"

# Now test it again
# !poetry --version

# %%
import os

# 1. Clone your repository directly into the Colab server
# !git clone https://github.com/leonardotorresaltez/routing-model-2025.git

# 2. Move into the project folder
# %cd routing-model-2025

# 3. Setup Poetry and install dependencies
os.environ['PATH'] += ":/root/.local/bin"
# !poetry config virtualenvs.create false
# !poetry install

print("✅ Project synced and installed!")

# %%
os.environ["WANDB_API_KEY"] = "INSERT_YOUR_API_KEY_HERE"

# %%
# !poetry run train
